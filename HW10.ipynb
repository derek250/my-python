# %% [markdown]
# ### 用 RNN 做情意分析

# %%
# %env KERAS_BACKEND=tensorflow
# Out:
# env: KERAS_BACKEND=tensorflow

# %%
# !pip install numpy==1.16.2
# Out:
# Requirement already satisfied: numpy==1.16.2 in /usr/local/lib/python3.6/dist-packages (1.16.2)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

from keras.preprocessing import sequence
from keras.datasets import imdb

from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)

# %%
x_train = sequence.pad_sequences(x_train, maxlen=400)
x_test = sequence.pad_sequences(x_test, maxlen=400)
#把輸入弄成一樣的長度

# %%
x_train.shape
# Out:
# (25000, 400)

# %%
N = 50 # 文字要壓到 N 維
K = 10 # LSTM 有 K 個神經元

# %%
model = Sequential()

model.add(Embedding(10000, N))
model.add(LSTM(K))

model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy' , optimizer='adam' , metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, None, 50)          500000
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 10)                2440
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 502,451
# Trainable params: 502,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
(4*(N+K)+4)*K
# Out:
# 2440

# %%
model.fit(x_train, y_train ,  batch_size=50 , epochs=3)
# Out:
# Epoch 1/3
# 25000/25000 [==============================] - 252s 10ms/step - loss: 0.4336 - acc: 0.7995
# Epoch 2/3
# 25000/25000 [==============================] - 252s 10ms/step - loss: 0.2513 - acc: 0.9061
# Epoch 3/3
# 25000/25000 [==============================] - 252s 10ms/step - loss: 0.1862 - acc: 0.9352

# %%
score = model.evaluate(x_test, y_test)
print(f'測試資料的 loss = {score[0]}')
print(f'測試資正確率 = {score[1]}')
# Out:
# 25000/25000 [==============================] - 80s 3ms/step
# 測試資料的 loss = 0.32910957076072694
# 測試資正確率 = 0.87248
